# %% [markdown]
# # Практикум программирования на Python

# %% [markdown]
# ## Выполнил: **Кривоногов Данил Юрьевич**
#
# ## Группа: **МИВТ-24-3-1 (Науки о данных)**

# %% [markdown]
# ### Домашнее задание 1

# %% [markdown]
# #### **Задача 1**. Сумма первых n положительных чисел
#
# Напишите программу, запрашивающую у пользователя число и подсчитывающую сумму натуральных положительных чисел от 1 до введенного пользователем значения.
#
# Сумма первых n положительных чисел может быть рассчитана по формуле:
#
# *sum = [n * (n + 1)] / 2*

# %%
def process_input(text_input: str) -> float:
    """
    Check the input text and convert it into a number.

    Parameters:
    -----------
    `text_input` : `str`
        The input text from user.

    Returns:
    --------
    `number` : `float`
        The number from user input.

    Raises:
    -------
    `ValueError`
        If the user input is not valid (empty or not a number).
    """
    if not len(text_input) > 0:
        raise ValueError(f"Your input: '{text_input}' is empty! Please enter a number.")
    
    try:
        number = float(text_input)
    except ValueError:
        raise ValueError(f"Your input: '{text_input}' is not a number! Please enter a number.")

    return number 

def calculate_sum(number: float) -> int:
    """
    Calculate the sum of natural positive numbers from 1 to number.

    Parameters:
    -----------
    `number` : `int`
        The number for calculation.

    Returns:
    --------
    `sum` : `int`
        The calculated sum.

    Raises:
    -------
    `ValueError`
        If the number is not greater then zero.
    """
    if number < 0:
        raise ValueError(f"Your number: {number} is less then zero! Please enter a number is greater than zero.") 
    
    number = int(number)

    sum = number * (number + 1) / 2
    sum = int(sum)

    return sum

def main():
    print("Input the number to get the sum of natural positive numbers from 1 to your number.")
    text_input = input("Number: ")
    print(f"Input is: {text_input}")

    number = process_input(text_input)
    sum = calculate_sum(number)

    print(f"The sum is: {sum}")


if __name__ == "__main__":
    main()
# Out:
# Input the number to get the sum of natural positive numbers from 1 to your number.
# Input is: 12.23
# The sum is: 78

# %% [markdown]
# #### **Задача 2**. Калькулятор
#
# Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:
#
# - арифметические: +, -, * , / , // , %, **, log10;
# - сравнение: <, <=, >, >=, !=, ==,
#
# выводя на экран результат каждого действия.
#
# В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).
#
# Подсказка. Функцию log10 вы найдете в модуле math.

# %%
from math import log10

def process_input(text_input: str) -> float:
    """
    Check the input text and convert it into a number.

    Parameters:
    -----------
    `text_input` : `str`
        The input text from user.

    Returns:
    --------
    `number` : `float`
        The number from user input.

    Raises:
    -------
    `ValueError`
        If the user input is not valid (empty or not a number).
    """
    if not len(text_input) > 0:
        raise ValueError(f"Your input: '{text_input}' is empty! Please enter a number.")
    
    try:
        number = float(text_input)
    except ValueError:
        raise ValueError(f"Your input: '{text_input}' is not a number! Please enter a number.")

    return number 

def perform_calculations(number_1: float, number_2: float) -> None:
    """
    Perform calculations on two numbers.

    Parameters:
    -----------
    `number_1` : `float`
        The first number for calculations.
    `number_2` : `float`
        The second number for calculations.

    Raises:
    -------
    `ValueError`
        - If the second number equals zero (division by zero).
        - If the first number is not greater than zero (only positive real numbers can be raised to a fractional rational power).
        - If the first or second number is not greater than zero (logarithm).
    """
    print("Calculations: ")

    print(f"{number_1} + {number_2} = {round((number_1 + number_2), 2)}")
    print(f"{number_1} - {number_2} = {round((number_1 - number_2), 2)}")

    if number_2 == 0:
        raise ValueError("The second number is zero! Please enter a non-zero number.")
    print(f"{number_1} / {number_2} = {round((number_1 / number_2), 2)}")
    print(f"{number_1} // {number_2} = {round((number_1 // number_2), 2)}")
    print(f"{number_1} % {number_2} = {round((number_1 % number_2), 2)}")
    
    if number_1 < 0:
        raise ValueError("The first number is not greater than zero! Please enter number greater than zero.")
    print(f"{number_1} ** {number_2} = {round((number_1 ** number_2), 2)}")

    if number_1 <= 0 or number_2 <= 0:
        raise ValueError("The first of second number is not greater than zero! Please enter numbers greater than zero.")
    print(f"log10({number_1}), log10({number_2}) = {round((log10(number_1)), 2)}, {round((log10(number_2)), 2)}")

    print(f"{number_1} < {number_2} = {number_1 < number_2}")
    print(f"{number_1} <= {number_2} = {number_1 <= number_2}")
    print(f"{number_1} > {number_2} = {number_1 > number_2}")
    print(f"{number_1} >= {number_2} = {number_1 >= number_2}")
    print(f"{number_1} != {number_2} = {number_1 != number_2}")
    print(f"{number_1} == {number_2} = {number_1 == number_2}")

def main():
    print("Input two numbers to get the result of calculations.")
    text_input_1 = input("Number 1: ")
    text_input_2 = input("Number 2: ")
    print(f"Input is: {text_input_1}, {text_input_2}")

    number_1 = process_input(text_input_1)
    number_2 = process_input(text_input_2)

    perform_calculations(number_1, number_2)


if __name__ == "__main__":
    main()
# Out:
# Input two numbers to get the result of calculations.
# Input is: 10, 23
# Calculations:
# 10.0 + 23.0 = 33.0
# 10.0 - 23.0 = -13.0
# 10.0 / 23.0 = 0.43
# 10.0 // 23.0 = 0.0
# 10.0 % 23.0 = 10.0
# 10.0 ** 23.0 = 1e+23
# log10(10.0), log10(23.0) = 1.0, 1.36
# 10.0 < 23.0 = True
# 10.0 <= 23.0 = True
# 10.0 > 23.0 = False
# 10.0 >= 23.0 = False
# 10.0 != 23.0 = True
# 10.0 == 23.0 = False

# %% [markdown]
# #### **Задача 3**.
#
# Вычислите значение следующего выражения (аргументы - целые числа и вводятся с клавиатуры):
#
# *f = [(((x ** 5) + 7) / (|-6| * y)) ** (1/3)] / [7 - z mod y]*
#
# Округлите результат до 3-х знаков после запятой, используя функцию round().

# %%
def process_input(text_input: str) -> float:
    """
    Check the input text and convert it into a number.

    Parameters:
    -----------
    `text_input` : `str`
        The input text from user.

    Returns:
    --------
    `number` : `float`
        The number from user input.

    Raises:
    -------
    `ValueError`
        If the user input is not valid (empty or not a number).
    """
    if not len(text_input) > 0:
        raise ValueError(f"Your input: '{text_input}' is empty! Please enter a number.")
    
    try:
        number = float(text_input)
    except ValueError:
        raise ValueError(f"Your input: '{text_input}' is not a number! Please enter a number.")

    return number 

def calculate_function_value(x: float, y: float, z: float) -> float:
    """
    Calculate the value of function f(x,y,z).

    Parameters:
    -----------
    `x` : `float`
        The first function argument.
    `y` : `float`
        The second function argument.
    `z` : `float`
        The third function argument.

    Returns:
    --------
    `result` : `float`
        The calculated value.

    Raises:
    -------
    `ValueError`
        - If the second argument equals zero (division by zero).
        - If the divider (7 - z mod y) is zero (division by zero).
        - If the number under the root is not greater than zero (only positive real numbers can be raised to a fractional rational power).
    """
    if y == 0:
        raise ValueError("Division by zero! Please enter another y value.")

    divider = 7 - z % y
    if divider == 0:
        raise ValueError("The divider (7 - z mod y) is zero! Please enter another pair of values (z, y).")

    number_under_the_root = ((x ** 5 + 7) / (6 * y))
    if number_under_the_root < 0:
        raise ValueError("The number under the root is not greater than zero! Please enter another pair of values (x, y).")
    
    value = (number_under_the_root ** (1/3)) / divider

    value = round(value, 3)

    return value

def main():
    print("Input three numbers to get the function value.")
    text_input_1 = input("Number 1: ")
    text_input_2 = input("Number 2: ")
    text_input_3 = input("Number 3: ")
    print(f"Input is: {text_input_1}, {text_input_2}, {text_input_3}")

    x = process_input(text_input_1)
    y = process_input(text_input_2)
    z = process_input(text_input_3)

    value = calculate_function_value(x, y, z)

    print(f"The function value is: {value}")


if __name__ == "__main__":
    main()
# Out:
# Input three numbers to get the function value.
# Input is: 23, 2143, 12324141
# The function value is: -0.004

# %% [markdown]
# #### **Задача 4**.
#
# Дана электрическая цепь, состоящая из 2-х последовательно соединенных проводников (сопротивление каждого известно).
#
# Найти общее сопротивление цепи (округление результата необходимо выполнить до 1-го знака после запятой).

# %%
def calculate_resistance(first_resistance: float, second_resistance: float) -> float:
    """
    Calculate the resistance of two conductors connected in series.

    Parameters:
    -----------
    `first_resistance` : `float`
        Resistance of the first element.
    `second_resistance` : `float`
        Resistance of the second element.

    Returns:
    --------
    `resistance` : `float`
        The calculated resistance.
    
    Raises:
    -------
    `ValueError`
        If any resistance is less than zero (not valid).
    """
    if first_resistance < 0 or second_resistance < 0:
        raise ValueError("The resistance is less than zero! Please enter another value of resistance.")

    resistance = first_resistance + second_resistance

    resistance = round(resistance, 1)

    return resistance

def main():
    print("Specify the resistance of the conductors (connected in series).")
    first_resistance = 10.3
    second_resistance = 23.241
    
    resistance = calculate_resistance(first_resistance, second_resistance)

    print(f"The resistance is: {resistance} (for resistances: {first_resistance}, {second_resistance})")


if __name__ == "__main__":
    main()
# Out:
# Specify the resistance of the conductors (connected in series).
# The resistance is: 33.5 (for resistances: 10.3, 23.241)

# %% [markdown]
# #### **Задача 5**.
#
# Дано уравнение *ax + b = 0* и отрезок [m;n].
#
# Ответьте на вопрос, попадает ли решение уравнения в указанный отрезок.

# %%
def solve_equation(a: float, b: float) -> float:
    """
    Find a solution to the equation ax + b = 0.

    Parameters:
    -----------
    `a` : `float`
        The first parameter.
    `b` : `float`
        The second parameter.

    Returns:
    --------
    `x` : `float`
        The solution of the equation.
    
    Raises:
    -------
    `ValueError`
        If first parameter (a) equals zero (division by zero). 
    """
    if a == 0:
        raise ValueError("Division by zero! Please enter another value of 'a'.")

    x = -b / a
    x = round(x, 7)

    return x

def is_point_in_segment(x: float, m: float, n: float) -> bool:
    """
    Checks whether the point belongs to the segment [m;n].

    Parameters:
    -----------
    `x` : `float`
        The point.
    `m` : `float`
        The beginning of the segment.
    `n` : `float`
        The end of the segment.

    Returns:
    --------
    `is_in_segment` : `float`
        The boolean value (True if the point belongs to the segment).
    
    Raises:
    -------
    `ValueError`
        If end of the segment less then beginning of the segment. 
    """
    if n < m:
        raise ValueError("End of the segment less then beginning of the segment! Please enter another values.")

    if x >= m and x <= n:
        is_in_segment = True
    else:
        is_in_segment = False

    return is_in_segment

def main():
    print("Specify the values of the parmeters (ax + b = 0) and values of the segment [m;n].")
    a = -18
    b = -0.54

    m = -3
    n = 5
    
    x = solve_equation(a, b)
    answer = is_point_in_segment(x, m, n)

    print(f"Does the solution ({x}) belongs to the segment [{m},{n}]? {answer}")


if __name__ == "__main__":
    main()
# Out:
# Specify the values of the parmeters (ax + b = 0) and values of the segment [m;n].
# Does the solution (-0.03) belongs to the segment [-3,5]? True

# %% [markdown]
# #### **Задача 6**. Поездка по кругу
#
# Спортсмен решил потренироваться перед марафоном и покататься вокруг города на скорость. Длина дороги — 123 километра.
#
# Спортсмен стартует с нулевого километра и едет со скоростью v километров в час. На какой отметке он остановится через t часов?
#
# Реализуйте программу, которая спрашивает у пользователя v и t и выводит целое число от 0 до 122 — номер километра, на котором остановится Спортсмен. Учтите, что он может прокатиться больше одного круга.

# %%
def process_input(text_input: str) -> float:
    """
    Check the input text and convert it into a number.

    Parameters:
    -----------
    `text_input` : `str`
        The input text from user.

    Returns:
    --------
    `number` : `float`
        The number from user input.

    Raises:
    -------
    `ValueError`
        If the user input is not valid (empty or not a number).
    """
    if not len(text_input) > 0:
        raise ValueError(f"Your input: '{text_input}' is empty! Please enter a number.")
    
    try:
        number = float(text_input)
    except ValueError:
        raise ValueError(f"Your input: '{text_input}' is not a number! Please enter a number.")

    return number 

def calculate_num_kilometer(v: float, t: float) -> int:
    """
    Сalculates the kilometer number where the sportsman will stop (the length of the lap is 123 kilometers).

    Parameters:
    -----------
    `v` : `float`
        The velocity of sportsman.
    `t` : `float`
        The duration of the ride.
    
    Returns:
    --------
    `kilometer` : `int`
        The kilometer number.

    Raises:
    -------
    `ValueError`
        - If the velocity or the time is less than zero.
    """
    if v < 0 or t < 0:
        raise ValueError("The velocity or the time is less than zero! Please enter valid values.")
        
    path_length = v * t
    kilometer = path_length % 123

    kilometer = int(kilometer)

    return kilometer

def main():
    print("Input velocity and time.")
    text_input_1 = input("Velocity: ")
    text_input_2 = input("Time: ")
    print(f"Velocity is: {text_input_1}, time is: {text_input_2}")

    v = process_input(text_input_1)
    t = process_input(text_input_2)

    kilometer = calculate_num_kilometer(v, t)

    print(f"The number of kilometer is: {kilometer}")


if __name__ == "__main__":
    main()
# Out:
# Input velocity and time.
# Velocity is: 123, time is: 1.5
# The number of kilometer is: 61

# %% [markdown]
# #### **Задача 7**. Сумма и произведение цифр в числе
#
# Дано двузначное и трехзначное число.
#
# Для каждого выведите на экран сумму и произведение цифр.

# %%
from typing import Tuple

def calculate_digits(number: int) -> Tuple[int, int]:
    """
    Сalculate the sum and product of digits.

    Parameters:
    -----------
    `number` : `int`
        Number for calculating.

    Returns:
    --------
    `result` : `Tuple[int, int]`
        The tuple with calculated sum and product of digits.
    """
    if number < 0:
        number = -number

    sum_of_digits = 0
    product_of_digits = 1

    while number > 0:
        digit = number % 10
        sum_of_digits += digit
        product_of_digits *= digit
        number //= 10

    return (sum_of_digits, product_of_digits)

def main():
    print("Specify the two-digit number and the three-digit number.")
    two_digit_number = 14
    three_digit_number = 293
    
    first_result = calculate_digits(two_digit_number)
    second_result = calculate_digits(three_digit_number)

    print(f"For two-digit number {two_digit_number} the result is (sum, product): {first_result}")
    print(f"For three-digit number {three_digit_number} the result is (sum, product): {second_result}")


if __name__ == "__main__":
    main()
# Out:
# Specify the two-digit number and the three-digit number.
# For two-digit number 14 the result is (sum, product): (5, 4)
# For three-digit number 293 the result is (sum, product): (14, 54)

# %% [markdown]
# #### **Задача 8**. Сортировка трех чисел
#
# Напишите программу, запрашивающую у пользователя три целых числа и выводящую их в упорядоченном виде – по возрастанию.
#
# Используйте функции min и max для нахождения наименьшего и наибольшего значений.
#
# Оставшееся число можно найти путем вычитания из суммы трех введенных чисел максимального и минимального.

# %%
from typing import Tuple

def process_input(text_input: str) -> float:
    """
    Check the input text and convert it into a number.

    Parameters:
    -----------
    `text_input` : `str`
        The input text from user.

    Returns:
    --------
    `number` : `float`
        The number from user input.

    Raises:
    -------
    `ValueError`
        If the user input is not valid (empty or not a number).
    """
    if not len(text_input) > 0:
        raise ValueError(f"Your input: '{text_input}' is empty! Please enter a number.")
    
    try:
        number = float(text_input)
    except ValueError:
        raise ValueError(f"Your input: '{text_input}' is not a number! Please enter a number.")

    return number 

def sort_three_numbers(num_1: float, num_2: float, num_3: float) -> Tuple[float, float, float]:
    """
    Sorts three numbers in ascending order.

    Parameters:
    -----------
    `num_1` : `float`
        The first number.
    `num_2` : `float`
        The second number.
    `num_1` : `float`
        The third number.
    
    Returns:
    --------
    `sorted_numbers` : `Tuple[float, float, float]`
        The tuple with sorted numbers.
    """
    numbers = (num_1, num_2, num_3)

    min_num = int(min(numbers))
    max_num = int(max(numbers))
    avg_num = int(sum(numbers) - min_num - max_num)

    return (min_num, avg_num, max_num)

def main():
    print("Input three numbers.")
    text_input_1 = input("Number 1: ")
    text_input_2 = input("Number 2: ")
    text_input_3 = input("Number 3: ")
    print(f"Your numbers are: {text_input_1}, {text_input_2}, {text_input_3}")

    num_1 = process_input(text_input_1)
    num_2 = process_input(text_input_2)
    num_3 = process_input(text_input_3)

    sorted_numbers = sort_three_numbers(num_1, num_2, num_3)

    print(f"Sorted numbers (min -> max): {sorted_numbers}")


if __name__ == "__main__":
    main()
# Out:
# Input three numbers.
# Your numbers are: 21, 32, 1
# Sorted numbers (min -> max): (1, 21, 32)

# %% [markdown]
# #### **Задача 9**. Поменять местами: не всё так просто!
#
# Напишите программу, которая меняла бы значения двух переменных местами, но без использования третьей переменной и синтаксического сахара, а именно — без конструкции
# a, b = b, a
#
# В переменные будут вводиться только числа.
# ```python
# a = int(input('Введите первое число: '))
# b = int(input('Введите второе число: '))
# print(a, b)
# # стереть эту строчку и вставить свой код здесь
# print(a, b)
# ```
#
# Изменять, удалять, менять местами 1-ю, 2-ю, 3-ю и последнюю строчки нельзя. Но между 3-ей и 4-ой строкой можно вставлять сколько угодно строк кода, не трогая последний принт.

# %%
a = int(input('Введите первое число: '))
b = int(input('Введите второе число: '))
print(a, b)

b = b + a
a = b - a # a = b, b = b + a
b = b - a

print(a, b)
# Out:
# 41 3
# 3 41

# %% [markdown]
# #### **Задача 10**.
#
# Составьте программу, которая запрашивает название футбольной команды и повторяет его на экране со словами
#
# ... - чемпион!
#
# После этого выполните:
# - используя операцию дублирования, нарисуйте черту (набор "-"), длиной, равной размеру названия команды;
# - преобразуйте строку в нижний регистр и выведите на экран:
#     - длину наименования команды;
#     - есть ли в наименовании команды буква "п" (True/False)?
#     - сколько раз повторяется буква "а"?

# %%
def main():
    print("Input the name of the footbal team.")
    text_input_1 = input("Footbal team: ")
    text_input_1 = text_input_1.replace(" ", "")

    print(f"{text_input_1} - чемпион!")

    print("-" * len(text_input_1))

    print(f"- строка в нижнем регистре: {text_input_1.lower()}")

    print(f"- длина наименования команды: {len(text_input_1)}")

    unique_chars: set = set(text_input_1)
    char_in_string: bool = False
    if 'п' in unique_chars:
        char_in_string = True
    print(f"- 'п' в названии команды: {char_in_string}")

    num_specified_char: int = 0
    for char_id in range(len(text_input_1)):
        char = text_input_1[char_id]
        if char == 'а':
            num_specified_char += 1
    print(f"- число повтоорений буквы 'а': {num_specified_char}")

if __name__ == "__main__":
    main()
# Out:
# Input the name of the footbal team.
# Спартак - чемпион!
# -------
# - строка в нижнем регистре: спартак
# - длина наименования команды: 7
# - 'п' в названии команды: True
# - число повтоорений буквы 'а': 2

# %% [markdown]
# #### **Задача 11**.
#
# Составьте программу, которая запрашивает название государства и его столицы, а затем выводит сообщение:
#
# Государство - ..., столица - ...
#
# На месте многоточий должны быть выведены соответствующие значения.

# %%
def main():
    print("Input the name of the state and the name of the capital.")
    text_input_1 = input("State: ")
    text_input_1 = text_input_1.replace(" ", "")
    text_input_2 = input("Capital: ")
    text_input_2 = text_input_2.replace(" ", "")

    print(f"Государство - {text_input_1}, столица - {text_input_2}")


if __name__ == "__main__":
    main()
# Out:
# Input the name of the state and the name of the capital.
# Государство - Россия, столица - Москва

# %% [markdown]
# #### **Задача 12**.
#
# Дано слово *объектно-ориентированный*.
#
# Используя индексацию и срезы составьте из него слова *объект*, *ориентир*, *тир*, *кот*, *рента* и выведите их на экран.

# %%
def main():
    original_string: str = "объектно-ориентированный"

    first_string = original_string[0:6]
    second_string = original_string[9:17]
    third_string = original_string[14:17]
    fourth_string = original_string[4] + original_string[7] + original_string[5]
    fifth_string = original_string[10] + original_string[12] + original_string[13] + original_string[5] + original_string[19]

    print(first_string, second_string, third_string, fourth_string, fifth_string)


if __name__ == "__main__":
    main()
# Out:
# объект ориентир тир кот рента

# %% [markdown]
# #### **Задача 13**.
#
# Создайте 2 пустых списка и выполните операции, описанные в заготовке.
#
# ```python
# # Создать 2 пустых списка
# a = # Удалите комментарий и допишите код
# b = # Удалите комментарий и допишите код
#
# # Добавить 2 вещественных числа (4.5 и 3.4) в список 'a' с помощью append
# a.append(# Удалите комментарий и допишите код)
# a.append(# Удалите комментарий и допишите код)
# # Добавить 2 вещественных числа (8.7, 1.3) в список 'a' с помощью extend
# a.extend(# Удалите комментарий и допишите код)
#
# # Добавить 2 вещественных числа (14.5, 3.4) в список 'b' с помощью append
# # Удалите комментарий и допишите код
#
# # Добавить 2 вещественных числа (8.7, 11.3) в список 'b'с помощью extend
# # Удалите комментарий и допишите код
#
# # Вставить целое число 100 на 2-е и 4-е место списка 'a'
# a.insert(# Удалите комментарий и допишите код)
# a.insert(# Удалите комментарий и допишите код)
#
# # Вставить целое число 200 на 1-е и 3-е место списка 'b'
# # Удалите комментарий и допишите код
#
# # Вывести списки на экран
# print("Исходные списки:")
# print(# Удалите комментарий и допишите код)
# print(# Удалите комментарий и допишите код)
#
# # Удалить первые элементы из списков 'a' и 'b'
# del # Удалите комментарий и допишите код
# del # Удалите комментарий и допишите код
#
# # Удалить элемент 100 из списка 'a'
# a.remove(# Удалите комментарий и допишите код)
# # Удалить элемент 200 из списка 'b'
# # Удалите комментарий и допишите код
#
# # Вывести списки на экран
# print("\nПосле удалений:")
# # Удалите комментарий и допишите код
#
# # Создать множества из списков 'a' и 'b', а также их пересечение
# sa = set(a)
# sb = # Удалите комментарий и допишите код
# sa_and_sb = # Удалите комментарий и допишите код
# # Вывести экран уникальные элементы каждого списка и общие
# print("\nУникальные элементы:")
# # Удалите комментарий и допишите код
# print("общие:", sa_and_sb)
#
# # Соединить списки 'a' и 'b'
# c = # Удалите комментарий и допишите код
#
# # Отсортировать список 'c' по возрастанию и убыванию
# c_asc = # Удалите комментарий и допишите код
# c_desc = # Удалите комментарий и допишите код
#
# # Среднее арифметическое элементов списка 'c', расположенных на четных местах
# sr_ar = # Удалите комментарий и допишите код
# # Среднее геометрическое элементов списка 'c', расположенных на нечетных местах
# sr_geom = # Удалите комментарий и допишите код
#
# # Максимальный и минимальный элементы
# c_max = # Удалите комментарий и допишите код
# c_min = # Удалите комментарий и допишите код
#
# # Вывести результаты на экран
# print("\nИтоговые:")
# print("3-й:", c)
# # Удалите комментарий и допишите код
#
#
#
#
# # --------------
# # Пример вывода:
# #
# # Исходные списки:
# # 1-й: [4.5, 100, 3.4, 100, 8.7, 1.3]
# # 2-й: [200, 14.5, 200, 3.4, 8.7, 11.3]
# #
# # После удалений:
# # 1-й: [3.4, 100, 8.7, 1.3]
# # 2-й: [14.5, 3.4, 8.7, 11.3]
# #
# # Уникальные элементы:
# # 1-й: {8.7, 1.3, 3.4, 100}
# # 2-й: {8.7, 11.3, 3.4, 14.5}
# # общие: {8.7, 3.4}
#
# # Итоговые:
# # 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# # Сортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# # Сортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# # Ср. арифм. = 29.00, ср. геометр. = 7.82
# # Макс. и мин.: 100 1.3
#
# ```

# %%
def main():
    # Создать 2 пустых списка
    a = list()
    b = list()

    # Добавить 2 вещественных числа (4.5 и 3.4) в список 'a' с помощью append
    a.append(4.5)
    a.append(3.4)
    # Добавить 2 вещественных числа (8.7, 1.3) в список 'a' с помощью extend
    a.extend([8.7, 1.3])

    # Добавить 2 вещественных числа (14.5, 3.4) в список 'b' с помощью append
    b.append(14.5)
    b.append(3.4)

    # Добавить 2 вещественных числа (8.7, 11.3) в список 'b'с помощью extend
    b.extend([8.7, 11.3])

    # Вставить целое число 100 на 2-е и 4-е место списка 'a'
    a.insert(1, 100)
    a.insert(3, 100)

    # Вставить целое число 200 на 1-е и 3-е место списка 'b'
    b.insert(0, 200)
    b.insert(2, 200)

    # Вывести списки на экран
    print("Исходные списки:")
    print(a)
    print(b)

    # Удалить первые элементы из списков 'a' и 'b'
    del a[0]
    del b[0]

    # Удалить элемент 100 из списка 'a'
    a.remove(100)
    # Удалить элемент 200 из списка 'b'
    b.remove(200)

    # Вывести списки на экран
    print("\nПосле удалений:")
    print(a)
    print(b)

    # Создать множества из списков 'a' и 'b', а также их пересечение
    sa = set(a)
    sb = set(b)
    sa_and_sb = sa & sb
    # Вывести экран уникальные элементы каждого списка и общие
    print("\nУникальные элементы:")
    print(f"1-й: {sa}")
    print(f"2-й: {sb}")
    print("общие:", sa_and_sb)

    # Соединить списки 'a' и 'b'
    c = a + b

    # Отсортировать список 'c' по возрастанию и убыванию
    c_asc = sorted(c)
    c_desc = sorted(c, reverse=True)

    # Среднее арифметическое элементов списка 'c', расположенных на четных местах
    sr_ar = sum(c[1::2]) / len(c[::2])
    # Среднее геометрическое элементов списка 'c', расположенных на нечетных местах
    sr_geom = 1
    for elem in c[0::2]:
        sr_geom *= elem
    sr_geom = pow(sr_geom, (1 / len(c[0::2])))
    sr_geom = round(sr_geom, 2)

    # Максимальный и минимальный элементы
    c_max = max(c)
    c_min = min(c)

    # Вывести результаты на экран
    print("\nИтоговые:")
    print("3-й:", c)
    print("Сортировка (возр.):", c_asc)
    print("Сортировка (убыв.):", c_desc)
    print("Ср. арифм. =", sr_ar, "Ср. геометр. =", sr_geom)
    print("Макс. и мин.:", c_max, c_min)


if __name__ == "__main__":
    main()
# Out:
# Исходные списки:
# [4.5, 100, 3.4, 100, 8.7, 1.3]
# [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# [3.4, 100, 8.7, 1.3]
# [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й: {8.7, 1.3, 3.4, 100}
# 2-й: {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. = 29.0 Ср. геометр. = 7.82
# Макс. и мин.: 100 1.3

# %% [markdown]
# #### **Задача 14**.
#
# Создайте пустой словарь для хранения информации о себе и выполните операции, описанные в заготовке.
#
# ```python
# # В данной задаче все значения задаются в коде (без input())
#
# # 1. Создание словаря
# # Создать пустой словарь
# info = # Удалите комментарий и допишите код
#
# # Добавить значения для ключей "фио", "дата_рождения", "место_рождения"
# info["фио"] = # Удалите комментарий и допишите код
# # Удалите комментарий и допишите код
# # Удалите комментарий и допишите код
#
# # Напечатать словарь
# print(info)
#
# # Создать ключ "хобби" со значением = список из строк -
# # наименований хобби (например "плавание" и т.д.)
# # Удалите комментарий и допишите код
#
# # Добавить "программирование" в список хобби
# # Удалите комментарий и допишите код
#
# # Создать ключ "животные" со значением = кортеж из строк -
# # имен домашних животных (например "кошка Мурка" и т.д.)
# # Удалите комментарий и допишите код
#
# # Создать ключ "ЕГЭ" и поместить в него пустой словарь
# # Удалите комментарий и допишите код
#
# # В словарь info["ЕГЭ"] добавить информацию о сданных экзаменах,
# # где ключ - наименование предмета, а значение - количество баллов
#
#
# # Удалите комментарий и допишите код
#
#
# # Добавить экзамен, который не был сдан, после чего удалить его
# # Удалите комментарий и допишите код
#
# # Создать ключ "вузы" и поместить в него пустой словарь
# # Удалите комментарий и допишите код
#
# # В словарь info["вузы"] добавить информацию о вузах,
# # где ключ - аббревиатура вуза, а значение -
# # количество баллов для специальности, на которую хотели поступить
# # Удалите комментарий и допишите код
#
#
# # 2. Вывод на экран
# print("Данные:")
# # Получившийся словарь
# # Удалите комментарий и допишите код
#
# # Список экзаменов ЕГЭ в алфавитном порядке
# # (используйте метод ``keys()``, преобразовав результат в кортеж)
# exams = # Удалите комментарий и допишите код
# print("Предметы:", exams)
# # Список вузов в алфавитном порядке
# uni = # Удалите комментарий и допишите код
# print("Вузы:", uni)
#
# # 3. Ответы на вопросы
# print("\nОтветы на вопросы:")
#
# # Выделить имя из info["фио"]
# name = # Удалите комментарий и допишите код
# # Начинается на гласную? (True/False)
# starts_with_vowel = # Удалите комментарий и допишите код
# print("* мое имя начинается на гласную букву:", starts_with_vowel)
#
# # Выделить месяц из info["дата_рождения"]
# month = # Удалите комментарий и допишите код
# # Родился зимой или летом? (True/False)
# born_in_winter_or_summer = # Удалите комментарий и допишите код
# print("* родился летом или зимой:", # Удалите комментарий и допишите код)
#
# # Количество хобби и первое из них
# hobbies_count = # Удалите комментарий и допишите код
# print("* у меня {} хобби, первое \"{}\"".format(# Удалите комментарий и допишите код))
#
# # Количество сданных экзаменов
# print("* после окончания школы сдавал {} экз.".format(# Удалите комментарий и допишите код))
#
#
# # Сумма баллов по экзаменам
# sum_mark = # Удалите комментарий и допишите код
# print("* сумма баллов = {}".format(# Удалите комментарий и допишите код))
#
# # Максимальный балл среди сданных
# max_mark = # Удалите комментарий и допишите код
# print("* макс. балл = {}".format(# Удалите комментарий и допишите код))
#
# # Количество вузов, в которые Вы проходите по баллам
# # Подсказка: определить, проходите Вы или нет, можно простым сравнением
# # суммы баллов с проходным баллом вуза - ``True/False``.
# # Для того, чтобы определить количество таких вузов, преобразуйте
# # сравнение в целое число (используя ``int()``) и сложите все сравниваемые вузы.
# vuz_count = # Удалите комментарий и допишите код
# print("* кол-во вузов в которые прохожу: {}".format(# Удалите комментарий и допишите код))
#
#
#
# # --------------
# # Пример вывода:
# #
# # {'фио': 'Иванов Иван Иванович', 'место_рождения': 'Париж',
# #  'дата_рождения': '01/09/1995'}
# # Данные:
# # {'фио': 'Иванов Иван Иванович', 'животные': ('кошка Мурка',),
# #  'вузы': {'МИРЭА': 240, 'МГУ': 295, 'МГТУ им. Баумана': 255},
# #  'хобби': ['игра на гитаре', 'туризм', 'программирование'],
# #  'ЕГЭ': {'Математика': 90, 'Информатика': 88, 'Русский язык': 67},
# #  'дата_рождения': '01/09/1995', 'место_рождения': 'Париж'}
# # Предметы: Информатика, Математика, Русский язык
# # Вузы: МГТУ им. Баумана, МГУ, МИРЭА
#
# # Ответы на вопросы:
# # * мое имя начинается на гласную букву: True
# # * родился летом или зимой: False
# # * у меня 3 хобби, первое "игра на гитаре"
# # * после окончания школы сдавал 3 экз.
# # * сумма баллов = 245
# # * макс. балл = 90
# # * кол-во вузов в которые прохожу: 1
# ```

# %%
from pprint import pprint

def main():
    # 1. Создание словаря
    # Создать пустой словарь
    info = {}

    # Добавить значения для ключей "фио", "дата_рождения", "место_рождения"
    info["фио"] = "Кривоногов Данил Юрьевич"
    info["дата_рождения"] = "10/10/2002"
    info["место_рождения"] = "Москва"

    # Напечатать словарь
    print(info)

    # Создать ключ "хобби" со значением = список из строк -
    # наименований хобби (например "плавание" и т.д.)
    info["хобби"] = ["плавание", "огородничество"]

    # Добавить "программирование" в список хобби
    info["хобби"].append("программирование")

    # Создать ключ "животные" со значением = кортеж из строк -
    # имен домашних животных (например "кошка Мурка" и т.д.)
    info["животные"] = ("кошка Мурка", "собака Роки")

    # Создать ключ "ЕГЭ" и поместить в него пустой словарь
    info["ЕГЭ"] = {}

    # В словарь info["ЕГЭ"] добавить информацию о сданных экзаменах,
    # где ключ - наименование предмета, а значение - количество баллов

    info["ЕГЭ"]['Физика'] = 95
    info["ЕГЭ"]['Математика'] = 78
    info["ЕГЭ"]['Русский язык'] = 98

    # Добавить экзамен, который не был сдан, после чего удалить его
    info["ЕГЭ"]['Китайский язык'] = 10
    del info["ЕГЭ"]['Китайский язык']
    
    # Создать ключ "вузы" и поместить в него пустой словарь
    info["вузы"] = {}

    # В словарь info["вузы"] добавить информацию о вузах,
    # где ключ - аббревиатура вуза, а значение -
    # количество баллов для специальности, на которую хотели поступить
    info["вузы"]['МГТУ им. Баумана'] = 270
    info["вузы"]['МИСиС'] = 268
    info["вузы"]['ИТМО'] = 294

    # 2. Вывод на экран
    print("Данные:")
    # Получившийся словарь
    pprint(info)

    # Список экзаменов ЕГЭ в алфавитном порядке
    # (используйте метод ``keys()``, преобразовав результат в кортеж)
    exams = tuple(sorted(info["ЕГЭ"].keys()))
    print("Предметы:", exams)
    # Список вузов в алфавитном порядке
    uni = tuple(sorted(info["вузы"].keys()))
    print("Вузы:", uni)

    # 3. Ответы на вопросы
    print("\nОтветы на вопросы:")

    # Выделить имя из info["фио"]
    name = info["фио"].split()[1]
    # Начинается на гласную? (True/False)
    starts_with_vowel: bool = name[0].lower() in "аеёиоуыэюя"
    print("* мое имя начинается на гласную букву:", starts_with_vowel)

    # Выделить месяц из info["дата_рождения"]
    month = info["дата_рождения"].split("/")[1]
    # Родился зимой или летом? (True/False)
    born_in_winter_or_summer: bool = month in ["12", "1", "2", "6", "7", "8"]
    print("* родился летом или зимой:", born_in_winter_or_summer)

    # Количество хобби и первое из них
    hobbies_count = len(info["хобби"])
    print("* у меня {} хобби, первое \"{}\"".format(hobbies_count, info["хобби"][0]))

    # Количество сданных экзаменов
    print("* после окончания школы сдавал {} экз.".format(len(info["ЕГЭ"])))

    # Сумма баллов по экзаменам
    sum_mark = sum(info["ЕГЭ"].values())
    print("* сумма баллов = {}".format(sum_mark))

    # Максимальный балл среди сданных
    max_mark = max(info["ЕГЭ"].values())
    print("* макс. балл = {}".format(max_mark))

    # Количество вузов, в которые Вы проходите по баллам
    # Подсказка: определить, проходите Вы или нет, можно простым сравнением
    # суммы баллов с проходным баллом вуза - ``True/False``.
    # Для того, чтобы определить количество таких вузов, преобразуйте
    # сравнение в целое число (используя ``int()``) и сложите все сравниваемые вузы.
    vuz_count = len([passing_mark for passing_mark in info["вузы"].values() if sum_mark > passing_mark])
    print("* кол-во вузов в которые прохожу: {}".format(vuz_count))


if __name__ == "__main__":
    main()
# Out:
# {'фио': 'Кривоногов Данил Юрьевич', 'дата_рождения': '10/10/2002', 'место_рождения': 'Москва'}
# Данные:
# {'ЕГЭ': {'Математика': 78, 'Русский язык': 98, 'Физика': 95},
#  'вузы': {'ИТМО': 294, 'МГТУ им. Баумана': 270, 'МИСиС': 268},
#  'дата_рождения': '10/10/2002',
#  'животные': ('кошка Мурка', 'собака Роки'),
#  'место_рождения': 'Москва',
#  'фио': 'Кривоногов Данил Юрьевич',
#  'хобби': ['плавание', 'огородничество', 'программирование']}
# Предметы: ('Математика', 'Русский язык', 'Физика')
# Вузы: ('ИТМО', 'МГТУ им. Баумана', 'МИСиС')
#
# Ответы на вопросы:
# * мое имя начинается на гласную букву: False
# * родился летом или зимой: False
# * у меня 3 хобби, первое "плавание"
# * после окончания школы сдавал 3 экз.
# * сумма баллов = 271
# * макс. балл = 98
# * кол-во вузов в которые прохожу: 2
